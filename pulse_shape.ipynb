# %%
import os
path = r"C:\Users\quantum1\Documents\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\pulse_sequences"

# %%
files = os.listdir(path)
oop_files = [file for file in files if 'rabi' in file]
old_files = [file for file in files if 'foo' in file]

# %%
oop_files
# Out:
# ['rabi_oop_test_ch1_0000.npy',
#  'rabi_oop_test_ch1_0001.npy',
#  'rabi_oop_test_ch1_0002.npy',
#  'rabi_oop_test_ch1_0003.npy',
#  'rabi_oop_test_ch1_0004.npy',
#  'rabi_oop_test_ch1_0005.npy',
#  'rabi_oop_test_ch1_0006.npy',
#  'rabi_oop_test_ch1_0007.npy',
#  'rabi_oop_test_ch1_0008.npy',
#  'rabi_oop_test_ch1_0009.npy',
#  'rabi_oop_test_ch1_0010.npy',
#  'rabi_oop_test_ch1_0011.npy',
#  'rabi_oop_test_ch1_0012.npy',
#  'rabi_oop_test_ch1_0013.npy',
#  'rabi_oop_test_ch1_0014.npy',
#  'rabi_oop_test_ch1_0015.npy',
#  'rabi_oop_test_ch1_0016.npy',
#  'rabi_oop_test_ch1_0017.npy',
#  'rabi_oop_test_ch1_0018.npy',
#  'rabi_oop_test_ch1_0019.npy',
#  'rabi_oop_test_ch1_0020.npy',
#  'rabi_oop_test_ch1_0021.npy',
#  'rabi_oop_test_ch1_0022.npy',
#  'rabi_oop_test_ch1_0023.npy',
#  'rabi_oop_test_ch1_0024.npy',
#  'rabi_oop_test_ch1_0025.npy',
#  'rabi_oop_test_ch1_0026.npy',
#  'rabi_oop_test_ch1_0027.npy',
#  'rabi_oop_test_ch1_0028.npy',
#  'rabi_oop_test_ch1_0029.npy',
# ...

# %%
old_files
# Out:
# ['foo_ch1_0000.npy',
#  'foo_ch1_0001.npy',
#  'foo_ch1_0002.npy',
#  'foo_ch1_0003.npy',
#  'foo_ch1_0004.npy',
#  'foo_ch1_0005.npy',
#  'foo_ch1_0006.npy',
#  'foo_ch1_0007.npy',
#  'foo_ch1_0008.npy',
#  'foo_ch1_0009.npy',
#  'foo_ch1_0010.npy',
#  'foo_ch1_0011.npy',
#  'foo_ch1_0012.npy',
#  'foo_ch1_0013.npy',
#  'foo_ch1_0014.npy',
#  'foo_ch1_0015.npy',
#  'foo_ch1_0016.npy',
#  'foo_ch1_0017.npy',
#  'foo_ch1_0018.npy',
#  'foo_ch1_0019.npy',
#  'foo_ch1_0020.npy',
#  'foo_ch1_0021.npy',
#  'foo_ch1_0022.npy',
#  'foo_ch1_0023.npy',
#  'foo_ch1_0024.npy',
#  'foo_ch1_0025.npy',
#  'foo_ch1_0026.npy',
#  'foo_ch1_0027.npy',
#  'foo_ch1_0028.npy',
#  'foo_ch1_0029.npy',
#  'foo_ch1_0030.npy',
#  'foo_ch1_0031.npy',
#  'foo_ch1_0032.npy',
#  'foo_ch1_0033.npy',
#  'foo_ch1_0034.npy',
#  'foo_ch1_0035.npy',
#  'foo_ch1_0036.npy',
#  'foo_ch1_0037.npy',
#  'foo_ch1_0038.npy',
#  'foo_ch1_0039.npy',
#  'foo_ch1_0040.npy',
#  'foo_ch1_0041.npy',
#  'foo_ch1_0042.npy',
# ...
