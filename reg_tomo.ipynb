# %%
import numpy as np
import os
import dill as pickle
import matplotlib.pyplot as plt
import pandas as pd
import sys
import hardware_control.wx_programs as wx
import hardware_control.bnc as bnc
from classes.generator import *
from hardware_control.hardware_config import *
from experiment_configuration.values import *
from classes.qubit_class import *
import daq.daq_programs_homo as daq
import classifiers.classifier as classifier
import seaborn as sns
import standard_sequences.reg_tomo as tomo

# %%
q1 = Qubit(q1_dict, readout_dict)
q2 = Qubit(q2_dict, readout_dict)
readout = Readout(readout_dict)
print(f"{q1}\n{q2}")

wx_addr = wx.get_wx_address()
main_directory = r"C:\Users\quantum1\Documents"
save_dir = rf"{main_directory}\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\data"
target_bnc_address_6 = "USB0::0x03EB::0xAFFF::411-433500000-0753::INSTR"
bnc.set_bnc_output(
    general_vals_dict["qubit_bnc"], power_dBm=13, bnc_addr=target_bnc_address_6
)
bnc.set_bnc_output(
    readout_dict["RO_LO"],
    power_dBm=readout_dict["RO_LO_pwr"],
    bnc_addr=bnc_address["target_bnc_black"],
)
bnc.set_bnc_output(
    general_vals_dict["TWPA_freq"],
    general_vals_dict["TWPA_pwr"],
    bnc_addr=bnc_address["big_agilent"],
)
# Out:
# Qubit(ro_amp=1, ROIF=0.10275000000000034, ge_ssm=-0.1145, ro_freq=6.72745, qubit_thr=[-10000, -600], ef_ssm=-0.2568, ge_amp=0.8, ef_amp=1.5, qubit_id=q1, RO_LO=6.6247, ge_time=81.17534608287957, RO_LO_pwr=16, IQ_angle=205, RO_IF=None, ro_dur=4000, ef_time=49.13671850689116)
# Qubit(ro_amp=1.5, ROIF=0.030899999999999928, ge_ssm=-0.154, ro_freq=6.6556, qubit_thr=[-10000, 1900], ef_ssm=-0.2962, ge_amp=0.8, ef_amp=1, qubit_id=q2, RO_LO=6.6247, ge_time=45.047198597262124, RO_LO_pwr=16, IQ_angle=85, RO_IF=None, ro_dur=4000, ef_time=None)

# %%
def run_tomo(
    q1: object,
    q2: object,
    general_vals_dict: dict,
    copief: int,
    copige: int,
    swap_freq: float,
    swap_time: float,
    reps: int,
    tomography: str,
):
    """
    Runs a single instance of the nonhermitian ef Rabi experiment (with an e-swap to Q2)
    and processes the resulting IQ data to compute probabilities vs. time.

    Returns:
        df_prob (pd.DataFrame): A DataFrame whose index is the time (computed as
                                np.linspace(0, sweep_time/1000, num_steps)) and which has
                                columns ['P_f', 'P_e', 'P_g'] corresponding to the probabilities
                                of the f, e, and g states respectively.
    """
    coswap = 1
    # Run the experiment
    tomo. gef_tomo(
    q1,
    q2,
    general_vals_dict,
    copief,
    coswap,
    copige,
    num_steps=3,
    swap_freq=swap_freq,
    swap_time=swap_time,
    phase=0,
    swap_amp=1,
    tomo_comp=tomography,
    buffer=0)

    wx.wx_set_and_amplitude_and_offset(
        amp=general_vals_dict["wx_amps"], offset=general_vals_dict["wx_offs"]
    )
    # Acquire the raw IQ data
    values = daq.run_daq_het_2q(
        q1, q2, num_patterns=3, num_records_per_pattern=reps, verbose=False
    )

    # Retrieve raw IQ data from the acquired values
    I1_raw = values.rec_readout_1[0]
    Q1_raw = values.rec_readout_1[1]
    I2_raw = values.rec_readout_2[0]
    Q2_raw = values.rec_readout_2[1]

    # Build a DataFrame from the IQ data for classification
    IQ_df = pd.DataFrame({"I1": I1_raw, "Q1": Q1_raw, "I2": I2_raw, "Q2": Q2_raw})

    # Classify the IQ data (classifier.classify returns a DataFrame that has a 'predicted' column)
    classified = classifier.classify(IQ_df)
    states = classified["predicted"]
    # Reshape the predicted states.
    # (Assume that classifier.reshape_for_exp returns an array of shape (num_steps, reps),
    #  where each row corresponds to a time step and holds all the state measurements for that step.)
    states_reshaped = classifier.reshape_for_exp(states, reps, 3)
    probabilties = classifier.probabilities(states_reshaped)
    population = classifier.population(states_reshaped)

    # Compute time values as the index for the DataFrame.
    #times = np.linspace(0, sweep_time / 1000, 3)

    # Build a DataFrame that holds the probability vs. time.
    df_prob = pd.DataFrame(
        {
           # "time": times,
            "P_f": probabilties["P_f"],
            "P_e": probabilties["P_e"],
            "P_g": probabilties["P_g"],
        },
    )

    return df_prob, values

# %%
reps = 1000
sweep_time = 10
swap_freq = -0.0195
swap_time = 0.5 * 6 / abs(swap_freq)
J = 0.1
tomography = "y"
df_prob, values = run_tomo(
    q1,
    q2,
    general_vals_dict,
    copief = 0,
    copige = 1,
    swap_freq = swap_freq,
    swap_time = swap_time,
    reps = reps,
    tomography = tomography,
)
# Out:
# writing to C:\arbsequences\strong_dispersive_withPython\test_pulse_ringupdown_bin\
# writing ch1
# writing ch2
# writing ch3
# writing ch4
# loading C:\arbsequences\strong_dispersive_withPython\test_pulse_ringupdown_bin\
# num_steps 3
# loading ch1
# loading ch2
# loading ch3
# loading ch4
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[4], line 7
#       5 J = 0.1
#       6 tomography = "y"
# ----> 7 df_prob, values = run_tomo(
#       8     q1,
#       9     q2,
#      10     general_vals_dict,
#      11     copief = 0,
#      12     copige = 1,
#      13     swap_freq = swap_freq,
#      14     swap_time = swap_time,
#      15     reps = reps,
#      16     tomography = tomography,
#      17 )
#
# Cell In[3], line 24, in run_tomo(q1, q2, general_vals_dict, copief, copige, swap_freq, swap_time, reps, tomography)
#      22 coswap = 1
#      23 # Run the experiment
# ---> 24 tomo. gef_tomo(
#      25 q1,
#      26 q2,
#      27 general_vals_dict,
#      28 copief,
#      29 coswap,
#      30 copige,
#      31 num_steps=3,
#      32 swap_freq=swap_freq,
#      33 swap_time=swap_time,
#      34 phase=0,
#      35 swap_amp=1,
#      36 tomo_comp=tomography,
#      37 buffer=0)
#      39 wx.wx_set_and_amplitude_and_offset(
#      40     amp=general_vals_dict["wx_amps"], offset=general_vals_dict["wx_offs"]
#      41 )
#      42 # Acquire the raw IQ data
#
# File c:\Users\quantum1\OneDrive\Documents\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\standard_sequences\reg_tomo.py:136, in gef_tomo(q1, q2, gen_vals_dict, copief, coswap, copige, num_steps, swap_freq, swap_time, phase, swap_amp, tomo_comp, buffer)
#     126 write_dir = (
#     127     r"C:\arbsequences\strong_dispersive_withPython\test_pulse_ringupdown_bin"
#     128 )
#     129 ringupdown_seq.write_sequence_to_disk(
#     130     base_name="foo",
#     131     file_path=write_dir,
#    (...)
#     134     write_binary=True,
#     135 )
# --> 136 ringupdown_seq.load_sequence_from_disk(
#     137     "128.252.134.31",
#     138     base_name="foo",
#     139     file_path=write_dir,
#     140     num_offset=0,
#     141     ch_amp=[1, 1, 1, 1],
#     142 )
#
# File c:\Users\quantum1\OneDrive\Documents\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\classes\generator.py:534, in Sequence.load_sequence_from_disk(self, instr_addr, base_name, file_path, num_offset, ch_amp)
#     532 inst.send_cmd(":TRAC:DEF 1,{0}".format(np.uint32(pseudo_seg_len)))
#     533 # select segment 1:
# --> 534 inst.send_cmd(":TRAC:SEL 1")
#     535 # download binary data:
#     536 inst.send_binary_data(":TRAC:DATA", wav_dat)
#
# File c:\Users\quantum1\OneDrive\Documents\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\hardware_control\tewx.py:588, in TEWXAwg.send_cmd(self, cmd_str, paranoia_level)
#     586     else:
#     587         ask_str += '*OPC?'
# --> 588     _ = self.send_query(ask_str)
#     589 elif paranoia_level >= 2:
#     590     ask_str = cmd_str.rstrip()
#
# File c:\Users\quantum1\OneDrive\Documents\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\hardware_control\tewx.py:622, in TEWXAwg.send_query(self, query_str)
#     620         query_str = np.fromstring(query_str, dtype=np.uint8)
#     621     self._tcp_sock.sendall(query_str)
# --> 622     resp = self.read_resp()
#     623 elif self._intf_type == CommIntfType.USB:
#     624     if isinstance(query_str, str):
#
# File c:\Users\quantum1\OneDrive\Documents\Python Scripts\Important Blue Fridge Python Files\New\nonlinear_QM\hardware_control\tewx.py:638, in TEWXAwg.read_resp(self)
#     636 if self._intf_type == CommIntfType.LAN:
#     637     ret = []
# --> 638     ch = self._tcp_sock.recv(1)
#     639     while b'\n' != ch and u'\n' != ch:
#     640         if b'\r' != ch and u'\r' != ch:
#
# KeyboardInterrupt:

# %%
df_prob
# Out:
#      P_f    P_e    P_g
# 0  0.437  0.165  0.398
# 1  0.448  0.148  0.404
# 2  0.427  0.144  0.429
